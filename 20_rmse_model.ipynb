# %%
import pandas as pd

# %%
aapl_data=pd.read_csv("AAPL.csv",parse_dates=True,index_col='Date')

# %%
allDates=pd.date_range(start=min(aapl_data.index),end=max(aapl_data.index),freq="D")

# %%
aapl_data.reindex(allDates[allDates.dayofweek<5]).isna().sum()
# Out:
# Open         74
# High         74
# Low          74
# Close        74
# Adj Close    74
# Volume       74
# dtype: int64

# %%
allDates=pd.date_range(start=min(aapl_data.index),end=max(aapl_data.index),freq="D")

# %%
aapl_data.reindex(allDates[allDates.dayofweek<5]).isna().sum()
# Out:
# Open         74
# High         74
# Low          74
# Close        74
# Adj Close    74
# Volume       74
# dtype: int64

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6))=plt.subplots(2,3,figsize=(20,10))
ax1.plot(aapl_data.index,aapl_data['Open'],label="Open")
ax1.legend(loc='best')
ax2.plot(aapl_data.index,aapl_data['High'],label="High")
ax2.legend(loc='best')
ax3.plot(aapl_data.index,aapl_data['Low'],label="Low")
ax3.legend(loc='best')
ax4.plot(aapl_data.index,aapl_data['Close'],label="Close")
ax4.legend(loc='best')
ax5.plot(aapl_data.index,aapl_data['Adj Close'],label="Adj Close")
ax5.legend(loc='best')
ax6.plot(aapl_data.index,aapl_data['Volume'],label="Volume")
ax6.legend(loc='best')

# %%
aapl_data.plot(y="Adj Close",figsize=(20,8))
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result=seasonal_decompose(aapl_data['Adj Close'], model='multiplicative',period=360)
val=result.plot()

# %%
import seaborn as sns
indexedData=pd.DataFrame({"Adj Close":aapl_data["Adj Close"]})
indexedData["Date"] = pd.to_datetime(aapl_data.index,format="%Y-%m-%d")

indexedData["Month"] = indexedData["Date"].dt.strftime("%m") # month extraction
indexedData["year"] = indexedData["Date"].dt.strftime("%Y")
plt.figure(figsize=(8,6))

plt.subplot(211)

sns.boxplot(x="Month",y="Adj Close", data= indexedData)

plt.subplot(212)

sns.boxplot (x="year",y="Adj Close", data=indexedData)
# Out:
# <Axes: xlabel='year', ylabel='Adj Close'>

# %%
aapl_data_missingdates=aapl_data.reindex(allDates[allDates.dayofweek<5])

# %%
interpolated_data=pd.DataFrame()
interpolated_data['Adj Close']=aapl_data_missingdates['Adj Close'].interpolate()

# %% [markdown]
# # **Train Test Split**

# %%
trainData=interpolated_data[interpolated_data.index<"2019-01-01"]

# %%
testData=interpolated_data[interpolated_data.index>="2019-01-01"]

# %%
trainData.plot(y="Adj Close",figsize=(20,8))
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %% [markdown]
# # **Make Data Stationary**

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(trainData)

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -1.260715
# p-value: 0.646948

# %% [markdown]
# the p value is greater than 0.05 so the data is non stationary

# %% [markdown]
# **Doing Log Transformation to make data stationary**

# %%
import numpy as np

logTrainData=np.log(trainData)
result = adfuller(logTrainData)

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -1.365735
# p-value: 0.598588

# %% [markdown]
# it is decreased a little but data is not still stationary

# %% [markdown]
# **Performing Squareroot transformation**

# %%
sqrtData=np.sqrt(trainData)
result = adfuller(sqrtData)

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -1.152656
# p-value: 0.693623

# %% [markdown]
# it had increased non stationarity with square root

# %% [markdown]
# **Lets perform Box Cox transformation**

# %%
from scipy.stats import boxcox

transformed_data, lambda_value = boxcox(trainData['Adj Close'])

# %%
result = adfuller(transformed_data)

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -1.540778
# p-value: 0.513251

# %% [markdown]
# not good with transformation lets try **Differenciation**

# %%
for i in range(1,50):
  transformData=trainData.diff(i)
  result = adfuller(transformData.dropna())

  print(f"p-value: { result[1]},at index {i}")
# Out:
# p-value: 1.3341054072513458e-10,at index 1
# p-value: 2.6825984772699946e-10,at index 2
# p-value: 1.2293829793218126e-09,at index 3
# p-value: 1.3572663357318076e-08,at index 4
# p-value: 1.5194685315199988e-07,at index 5
# p-value: 3.966098834275242e-08,at index 6
# p-value: 1.0074629183305102e-09,at index 7
# p-value: 1.498335825996641e-07,at index 8
# p-value: 3.253508128364593e-10,at index 9
# p-value: 7.019387421460536e-08,at index 10
# p-value: 6.540880325731487e-08,at index 11
# p-value: 6.286482260663946e-07,at index 12
# p-value: 1.864546500610738e-13,at index 13
# p-value: 8.441847561156893e-12,at index 14
# p-value: 1.7618275445020582e-10,at index 15
# p-value: 4.637478652950434e-10,at index 16
# p-value: 3.774953767091419e-08,at index 17
# p-value: 1.653594658266849e-06,at index 18
# p-value: 5.457514813070125e-06,at index 19
# p-value: 6.588825106002823e-06,at index 20
# p-value: 0.0002798068767511937,at index 21
# p-value: 0.00013394207123615016,at index 22
# p-value: 0.00042797014260905966,at index 23
# p-value: 4.52586523495776e-05,at index 24
# p-value: 0.00021936041727108432,at index 25
# p-value: 2.6588873450256373e-14,at index 26
# p-value: 2.011426431614841e-14,at index 27
# p-value: 1.488649923984382e-12,at index 28
# p-value: 2.4593821208270774e-12,at index 29
# p-value: 1.4532295208083428e-10,at index 30
# p-value: 9.205980313151994e-10,at index 31
# p-value: 9.56418489748982e-10,at index 32
# p-value: 1.7335484890232928e-10,at index 33
# p-value: 8.15992662908978e-09,at index 34
# p-value: 2.50960883205028e-07,at index 35
# p-value: 7.230303458921679e-07,at index 36
# p-value: 4.680112023347146e-06,at index 37
# p-value: 2.9384981795240283e-05,at index 38
# p-value: 1.9308812052766824e-06,at index 39
# p-value: 4.886224023242717e-06,at index 40
# p-value: 2.8107730401426336e-05,at index 41
# p-value: 0.0006548977528937603,at index 42
# p-value: 8.26597446499562e-05,at index 43
# p-value: 8.793815310479393e-06,at index 44
# p-value: 6.083839449756415e-06,at index 45
# p-value: 1.8921002622440063e-05,at index 46
# p-value: 3.0581378844065335e-05,at index 47
# p-value: 9.204994134912446e-06,at index 48
# p-value: 3.3033050620119316e-05,at index 49

# %% [markdown]
# differensiation worked we got perfectly non stationary data at index i

# %%
stationaryData=trainData.diff(1)
stationaryData=stationaryData.dropna()
result = adfuller(stationaryData)
print(f"p-value: { result[1]}")
# Out:
# p-value: 1.3341054072513458e-10

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
acf=plot_acf(stationaryData)

# %% [markdown]
# q=0

# %%
pacf=plot_pacf(stationaryData)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# p is 0

# %% [markdown]
# d=1

# %%
from statsmodels.tsa.arima.model import ARIMA

model=ARIMA(trainData,order=(0,1,0))
model_fit=model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              Adj Close   No. Observations:                 1825
# Model:                 ARIMA(0, 1, 0)   Log Likelihood               -3614.281
# Date:                Mon, 10 Apr 2023   AIC                           7230.562
# Time:                        20:01:31   BIC                           7236.071
# Sample:                    01-03-2012   HQIC                          7232.594
#                          - 12-31-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         3.0807      0.047     65.540      0.000       2.989       3.173
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.28   Jarque-Bera (JB):              4359.17
# Prob(Q):                              0.04   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.20   Skew:                            -0.52
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction_train=model_fit.predict(min(trainData.index),max(trainData.index))

# %%
import matplotlib.pyplot as plt

plt.plot(trainData.index,trainData['Adj Close'],label="original")
plt.plot(prediction_train.index,prediction_train,ls="--",label="prediction")
plt.legend(loc="best")
plt.show()

# %%
prediction_test=model_fit.predict(min(testData.index),max(testData.index))
plt.plot(testData.index,testData['Adj Close'],label="original")
plt.plot(prediction_test.index,prediction_test,ls="--",label="prediction")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# it clearly didin't understand test data but it is understood training data it is clear case of overfitting

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(trainData, prediction_train))
# Out:
# 2.1192294512423633

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(testData, prediction_test))
# Out:
# 61.61206617096474

# %%
for i in range(1,50):
  transformData=logTrainData.diff(i)
  result = adfuller(transformData.dropna())

  print(f"p-value: { result[1]},at index {i}")
# Out:
# p-value: 0.0,at index 1
# p-value: 1.1268495372303326e-12,at index 2
# p-value: 5.0039417344070366e-11,at index 3
# p-value: 5.856160522979519e-10,at index 4
# p-value: 6.264675946349696e-09,at index 5
# p-value: 9.50509951453111e-09,at index 6
# p-value: 1.9093719594298083e-09,at index 7
# p-value: 5.0002146234652744e-08,at index 8
# p-value: 4.722382466480612e-10,at index 9
# p-value: 9.23352323376063e-09,at index 10
# p-value: 4.3758537229950363e-08,at index 11
# p-value: 3.2636234995096295e-07,at index 12
# p-value: 5.656894366307466e-12,at index 13
# p-value: 2.0539042788201817e-11,at index 14
# p-value: 9.771421231239964e-10,at index 15
# p-value: 2.2928003999746253e-09,at index 16
# p-value: 3.4330048400866104e-08,at index 17
# p-value: 4.769696340835744e-07,at index 18
# p-value: 1.974027583852519e-07,at index 19
# p-value: 3.910386074604902e-07,at index 20
# p-value: 2.3166916803959893e-06,at index 21
# p-value: 3.1905467383274804e-06,at index 22
# p-value: 8.31604588222238e-06,at index 23
# p-value: 6.689113773704587e-06,at index 24
# p-value: 2.653889209308055e-05,at index 25
# p-value: 1.594060772472103e-13,at index 26
# p-value: 1.7123710204085051e-13,at index 27
# p-value: 2.7103798462404652e-12,at index 28
# p-value: 5.765322974558316e-11,at index 29
# p-value: 1.1738455757739637e-10,at index 30
# p-value: 7.457361716016576e-10,at index 31
# p-value: 1.3904229194272639e-09,at index 32
# p-value: 2.04324446834043e-09,at index 33
# p-value: 9.335070878042828e-06,at index 34
# p-value: 5.741127971429925e-08,at index 35
# p-value: 1.8114215959869177e-07,at index 36
# p-value: 5.0408287009969626e-05,at index 37
# p-value: 1.0527364660803257e-06,at index 38
# p-value: 5.63080594291223e-06,at index 39
# p-value: 3.05659356519133e-05,at index 40
# p-value: 3.5414609882106696e-06,at index 41
# p-value: 4.162338149063012e-05,at index 42
# p-value: 0.0010193836054564328,at index 43
# p-value: 7.252420409716515e-06,at index 44
# p-value: 0.0006129683729779893,at index 45
# p-value: 4.038020756695633e-06,at index 46
# p-value: 0.0019680575241285037,at index 47
# p-value: 7.976096100627237e-06,at index 48
# p-value: 1.6493562470799618e-05,at index 49

# %%
log_transform_data_train=logTrainData.diff(1)
log_transform_data_train=log_transform_data_train.dropna()

# %%
import seaborn as sns
sns.set()
acf=plot_acf(log_transform_data_train)

# %%
pacf=plot_pacf(log_transform_data_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
model=ARIMA(logTrainData,order=(0,1,0))
model_fit=model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %%
log_transform_train_prediction=model_fit.predict(min(trainData.index),max(trainData.index))

# %%
train_prediction=np.exp(log_transform_train_prediction)

# %%
plt.plot(trainData.index,trainData['Adj Close'],label="original")
plt.plot(train_prediction.index,train_prediction,ls="--",label="prediction")
plt.show()

# %%
log_transform_test_prediction=model_fit.predict(min(testData.index),max(testData.index))

# %%
test_prediction=np.exp(log_transform_test_prediction)

# %%
plt.plot(testData.index,testData['Adj Close'],label="original")
plt.plot(test_prediction.index,test_prediction,ls="--",label="prediction")
plt.show()

# %% [markdown]
# it didn't understood testing data as well

# %%
for i in range(1,50):
  transformData=sqrtData.diff(i)
  result = adfuller(transformData.dropna())

  print(f"p-value: { result[1]},at index {i}")
# Out:
# p-value: 0.0,at index 1
# p-value: 2.933573519941397e-11,at index 2
# p-value: 2.1882446919263738e-10,at index 3
# p-value: 2.4250941874316003e-09,at index 4
# p-value: 2.6098491849301183e-08,at index 5
# p-value: 1.503437516338643e-08,at index 6
# p-value: 5.429293425765018e-10,at index 7
# p-value: 6.783388366190495e-08,at index 8
# p-value: 3.254427181319379e-10,at index 9
# p-value: 3.345636483780726e-08,at index 10
# p-value: 4.415611267823833e-08,at index 11
# p-value: 4.0770623798085785e-07,at index 12
# p-value: 7.11375299862695e-13,at index 13
# p-value: 1.0273264531635984e-11,at index 14
# p-value: 7.037229619191798e-10,at index 15
# p-value: 1.099301149878317e-09,at index 16
# p-value: 3.647441352599296e-08,at index 17
# p-value: 6.96046727544698e-07,at index 18
# p-value: 1.552084702622409e-06,at index 19
# p-value: 2.3698374098681794e-06,at index 20
# p-value: 2.1230892699705686e-05,at index 21
# p-value: 7.408170059214478e-06,at index 22
# p-value: 2.972331019506257e-05,at index 23
# p-value: 1.855282134430768e-05,at index 24
# p-value: 8.566929446275767e-05,at index 25
# p-value: 3.065488745230013e-14,at index 26
# p-value: 6.546129349436588e-14,at index 27
# p-value: 2.0551025780294964e-12,at index 28
# p-value: 1.2883868605656814e-11,at index 29
# p-value: 1.5913237914067344e-10,at index 30
# p-value: 1.6982082587345863e-09,at index 31
# p-value: 1.2937211334968327e-09,at index 32
# p-value: 5.11045530274579e-10,at index 33
# p-value: 2.413692728041083e-05,at index 34
# p-value: 3.996708096201445e-08,at index 35
# p-value: 9.604756218248965e-07,at index 36
# p-value: 3.484079648805928e-06,at index 37
# p-value: 1.6899131920393943e-05,at index 38
# p-value: 3.4267281995411986e-06,at index 39
# p-value: 0.00029857653705155367,at index 40
# p-value: 1.0309745389942436e-05,at index 41
# p-value: 6.40328732137973e-05,at index 42
# p-value: 1.9364825357091892e-05,at index 43
# p-value: 7.510035498681184e-06,at index 44
# p-value: 5.515973736539453e-06,at index 45
# p-value: 5.8507884320053265e-06,at index 46
# p-value: 2.2331974330008154e-05,at index 47
# p-value: 2.4211570364348093e-05,at index 48
# p-value: 7.760646220105448e-05,at index 49

# %%
sqrt_transform_data_train=sqrtData.diff(1)
sqrt_transform_data_train=sqrt_transform_data_train.dropna()

# %%
acf=plot_acf(sqrt_transform_data_train)

# %%
pacf=plot_pacf(sqrt_transform_data_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
model=ARIMA(sqrtData,order=(0,1,0))
model_fit=model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %%
sqrt_transform_train_prediction=model_fit.predict(min(trainData.index),max(trainData.index))

# %%
prediction_train=np.square(sqrt_transform_train_prediction)

# %%
plt.plot(trainData.index,trainData['Adj Close'],label="original")
plt.plot(prediction_train.index,prediction_train,ls="--",label="prediction")
plt.show()

# %%
sqrt_transform_test_prediction=model_fit.predict(min(testData.index),max(testData.index))

# %%
prediction_test=np.square(sqrt_transform_test_prediction)

# %%
plt.plot(testData.index,testData['Adj Close'],label="original")
plt.plot(prediction_test.index,prediction_test,ls="--",label="prediction")
plt.show()

# %%
trainData.plot(figsize=(20,8))
plt.show()

# %%
trainData.plot(y="Adj Close",figsize=(20,10))
for i in range(10,20):
  trainData["Adj Close"].rolling(i).mean().plot(label=f"{i}")
plt.legend(loc="best")

# %%
trainData.plot(y="Adj Close",figsize=(20,10))
trainData["Adj Close"].rolling(30).mean().plot(label=f"20")
plt.legend(loc="best")

# %%
import statsmodels.api as sm
decompose_additive=sm.tsa.seasonal_decompose(trainData,period=30,model="additive")

# %%
import statsmodels.api as sm
decompose_multiplicative=sm.tsa.seasonal_decompose(trainData,period=30,model="multiplicative")

# %%
result_additive = adfuller(decompose_additive.resid.dropna())
result_multiplicative = adfuller(decompose_multiplicative.resid.dropna())

if(result_additive[1]<result_multiplicative[1]):
  print('model is additive')
else:
  print('model is multiplicative')
# Out:
# model is multiplicative

# %%
result_multiplicative[1]
# Out:
# 9.65041023830662e-21

# %% [markdown]
# residuals are stationary

# %%
residuals=decompose_multiplicative.resid.dropna()

# %%
acf=plot_acf(residuals,lags=90)

# %% [markdown]
# q=5

# %%
pacf=plot_pacf(residuals)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# p=1

# %%
residuals
# Out:
# 2012-01-24    0.948821
# 2012-01-25    0.998631
# 2012-01-26    0.990010
# 2012-01-27    0.990967
# 2012-01-30    0.993401
#                 ...
# 2018-12-04    1.019350
# 2018-12-05    1.018970
# 2018-12-06    1.020952
# 2018-12-07    0.993570
# 2018-12-10    1.004530
# Name: resid, Length: 1795, dtype: float64

# %%
model=ARIMA(decompose_multiplicative.resid,order=(1,0,5))
model_fit=model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
predict_train_resid=model_fit.predict(min(trainData.index),max(trainData.index))

# %%
decompose_multiplicative.trend.fillna(decompose_multiplicative.trend.mean(),inplace=True)

# %%
predictData=predict_train_resid*decompose_multiplicative.trend*decompose_multiplicative.seasonal

# %%
predictData.plot(y="Adj Close")
trainData['Adj Close'].plot()
# Out:
# <Axes: >

# %%
predict_test_resid=model_fit.predict(min(testData.index),max(testData.index))

# %%
trend_test=decompose_multiplicative.trend[(-len(predict_test_resid)):]

# %%
seasonal_test=decompose_multiplicative.seasonal[(-len(predict_test_resid)):]

# %%
test_predict=pd.DataFrame({"trend":trend_test,"seasonal":seasonal_test,"Date":predict_test_resid.index})

# %%
test_predict.set_index('Date',inplace=True)

# %%
predicted_data_test=predict_test_resid*test_predict['trend']*test_predict['seasonal']

# %%
predicted_data_test.plot(y="Adj Close")
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
trainData['Adj Close'].plot(figsize=(20,8))
predicted_data_test.plot(y="Adj Close")
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(trainData, predictData))
# Out:
# 6.914381558056999

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(testData, predicted_data_test))
# Out:
# 51.04938452812446

# %%
result_additive[1]
# Out:
# 4.5733821965837213e-20

# %%
residuals=decompose_additive.resid.dropna()

# %%
acf=plot_acf(residuals)

# %%
pacf=plot_pacf(residuals)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
model=ARIMA(decompose_additive.resid,order=(13,0,5))
model_fit=model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.9/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
decompose_additive.trend.fillna(decompose_additive.trend.mean(),inplace=True)

# %%
predictData=predict_train_resid+decompose_additive.trend+decompose_additive.seasonal

# %%
predictData.plot(y="Adj Close")
trainData['Adj Close'].plot()
# Out:
# <Axes: >

# %%
predict_test_resid=model_fit.predict(min(testData.index),max(testData.index))

# %%
trend_test=decompose_additive.trend[(-len(predict_test_resid)):]

# %%
seasonal_test=decompose_additive.seasonal[(-len(predict_test_resid)):]

# %%
test_predict=pd.DataFrame({"trend":trend_test,"seasonal":seasonal_test,"Date":predict_test_resid.index})

# %%
test_predict.set_index('Date',inplace=True)

# %%
predicted_data_test=predict_test_resid+test_predict['trend']+test_predict['seasonal']

# %%
predicted_data_test.plot(y="Adj Close")
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
trainData['Adj Close'].plot(figsize=(20,8))
predicted_data_test.plot(y="Adj Close")
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(trainData, predictData))
# Out:
# 7.3097519780258775

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(testData, predicted_data_test))
# Out:
# 50.97828478243122

# %%
adfuller(decompose_multiplicative.seasonal)[1]
# Out:
# 0.0

# %% [markdown]
# seasonal data is complitely stationary lets plot acf and pacf

# %%
pacf=plot_pacf(decompose_multiplicative.seasonal)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# P=32

# %%
acf=plot_acf(decompose_multiplicative.seasonal)

# %% [markdown]
# Q=24

# %% [markdown]
# m=35

# %% [markdown]
# Holts Winter method

# %%
m = 240
alpha = 1/(2*m)
from statsmodels.tsa.holtwinters import SimpleExpSmoothing   
# double and triple exponential smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
smmodel=SimpleExpSmoothing(trainData['Adj Close']).fit(smoothing_level=alpha)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %%
smmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ==============================================================================
# Dep. Variable:              Adj Close   No. Observations:                 1825
# Model:             SimpleExpSmoothing   SSE                        1641092.414
# Optimized:                       True   AIC                          12416.806
# Trend:                           None   BIC                          12427.824
# Seasonal:                        None   AICC                         12416.828
# Seasonal Periods:                None   Date:                 Mon, 10 Apr 2023
# Box-Cox:                        False   Time:                         20:02:26
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.0020833                alpha                False
# initial_level              79.329872                  l.0                 True
# ------------------------------------------------------------------------------
# """

# %%
predictTrainSM=smmodel.predict(min(trainData.index),max(trainData.index))

# %%
predictTrainSM.plot()
trainData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
predictTestSM=smmodel.predict(min(testData.index),max(testData.index))

# %%
predictTestSM.plot()
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
mse = mean_squared_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Squared Error (MSE) = ',mse)
rmse = np.round(np.sqrt(mse),2)
print(f'Root Mean Squared Error (RMSE) = ',rmse)
mae = mean_absolute_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Absolute Error (MAE)  = ', mae)
mape = mean_absolute_percentage_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Absolute Percentage Error (MAPE)  = ', mape)
# Out:
# Mean Squared Error (MSE) =  899.2287198948139
# Root Mean Squared Error (RMSE) =  29.99
# Mean Absolute Error (MAE)  =  22.98305139987272
# Mean Absolute Percentage Error (MAPE)  =  0.19395818820232644

# %%
mse = mean_squared_error(testData['Adj Close'],predictTestSM)
print(f'Mean Squared Error (MSE) = ',mse)
rmse = np.round(np.sqrt(mse),2)
print(f'Root Mean Squared Error (RMSE) = ',rmse)
mae = mean_absolute_error(testData['Adj Close'],predictTestSM)
print(f'Mean Absolute Error (MAE)  = ', mae)
mape = mean_absolute_percentage_error(testData['Adj Close'],predictTestSM)
print(f'Mean Absolute Percentage Error (MAPE)  = ', mape)
# Out:
# Mean Squared Error (MSE) =  4856.4541883318625
# Root Mean Squared Error (RMSE) =  69.69
# Mean Absolute Error (MAE)  =  60.35554125319693
# Mean Absolute Percentage Error (MAPE)  =  0.274435363713565

# %%
m = 20
alpha = 1/(2*m)
from statsmodels.tsa.holtwinters import SimpleExpSmoothing   
# double and triple exponential smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
smmodel=SimpleExpSmoothing(trainData['Adj Close']).fit(smoothing_level=alpha)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %%
smmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ==============================================================================
# Dep. Variable:              Adj Close   No. Observations:                 1825
# Model:             SimpleExpSmoothing   SSE                         135110.013
# Optimized:                       True   AIC                           7859.730
# Trend:                           None   BIC                           7870.748
# Seasonal:                        None   AICC                          7859.752
# Seasonal Periods:                None   Date:                 Mon, 10 Apr 2023
# Box-Cox:                        False   Time:                         20:02:29
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.0250000                alpha                False
# initial_level              61.468886                  l.0                 True
# ------------------------------------------------------------------------------
# """

# %%
predictTrainSM=smmodel.predict(min(trainData.index),max(trainData.index))

# %%
predictTrainSM.plot()
trainData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
predictTestSM=smmodel.predict(min(testData.index),max(testData.index))

# %%
predictTestSM.plot()
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
mse = mean_squared_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Squared Error (MSE) = ',mse)
rmse = np.round(np.sqrt(mse),2)
print(f'Root Mean Squared Error (RMSE) = ',rmse)
mae = mean_absolute_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Absolute Error (MAE)  = ', mae)
mape = mean_absolute_percentage_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Absolute Percentage Error (MAPE)  = ', mape)
# Out:
# Mean Squared Error (MSE) =  74.03288401345145
# Root Mean Squared Error (RMSE) =  8.6
# Mean Absolute Error (MAE)  =  6.590865741724038
# Mean Absolute Percentage Error (MAPE)  =  0.062328355528743676

# %%
mse = mean_squared_error(testData['Adj Close'],predictTestSM)
print(f'Mean Squared Error (MSE) = ',mse)
rmse = np.round(np.sqrt(mse),2)
print(f'Root Mean Squared Error (RMSE) = ',rmse)
mae = mean_absolute_error(testData['Adj Close'],predictTestSM)
print(f'Mean Absolute Error (MAE)  = ', mae)
mape = mean_absolute_percentage_error(testData['Adj Close'],predictTestSM)
print(f'Mean Absolute Percentage Error (MAPE)  = ', mape)
# Out:
# Mean Squared Error (MSE) =  1755.603167724008
# Root Mean Squared Error (RMSE) =  41.9
# Mean Absolute Error (MAE)  =  31.80161756698396
# Mean Absolute Percentage Error (MAPE)  =  0.1429610758232284

# %%
emamodel=ExponentialSmoothing(trainData['Adj Close'],trend='mul',seasonal='mul',seasonal_periods=360).fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
emamodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                Adj Close   No. Observations:                 1825
# Model:             ExponentialSmoothing   SSE                           4172.613
# Optimized:                         True   AIC                           2237.207
# Trend:                   Multiplicative   BIC                           4242.605
# Seasonal:                Multiplicative   AICC                          2421.462
# Seasonal Periods:                   360   Date:                 Mon, 10 Apr 2023
# Box-Cox:                          False   Time:                         20:02:56
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.9950027                alpha                 True
# smoothing_trend                0.0007464                 beta                 True
# smoothing_seasonal            9.9846e-05                gamma                 True
# initial_level                  67.173217                  l.0                 True
# initial_trend                  1.0027889                  b.0                 True
# initial_seasons.0              0.9312616                  s.0                 True
# initial_seasons.1              0.9560896                  s.1                 True
# initial_seasons.2              0.9634361                  s.2                 True
# initial_seasons.3              0.9688435                  s.3                 True
# initial_seasons.4              0.9875264                  s.4                 True
# initial_seasons.5              0.9780601                  s.5                 True
# initial_seasons.6              0.9825600                  s.6                 True
# initial_seasons.7              0.9830045                  s.7                 True
# initial_seasons.8              0.9752929                  s.8                 True
# initial_seasons.9              0.9873549                  s.9                 True
# initial_seasons.10             0.9937125                 s.10                 True
# initial_seasons.11             0.9988780                 s.11                 True
# initial_seasons.12             1.0010241                 s.12                 True
# initial_seasons.13             0.9914611                 s.13                 True
# initial_seasons.14             0.9892588                 s.14                 True
# initial_seasons.15             1.0026368                 s.15                 True
# initial_seasons.16             1.0102587                 s.16                 True
# initial_seasons.17             1.0001462                 s.17                 True
# initial_seasons.18             0.9912490                 s.18                 True
# initial_seasons.19             0.9922674                 s.19                 True
# initial_seasons.20             1.0054601                 s.20                 True
# initial_seasons.21             1.0184297                 s.21                 True
# initial_seasons.22             1.0050769                 s.22                 True
# initial_seasons.23             1.0109815                 s.23                 True
# initial_seasons.24             1.0186402                 s.24                 True
# initial_seasons.25             1.0321642                 s.25                 True
# initial_seasons.26             1.0403688                 s.26                 True
# initial_seasons.27             1.0359574                 s.27                 True
# initial_seasons.28             1.0414118                 s.28                 True
# initial_seasons.29             1.0472151                 s.29                 True
# initial_seasons.30             1.0577108                 s.30                 True
# initial_seasons.31             1.0571114                 s.31                 True
# initial_seasons.32             1.0530661                 s.32                 True
# initial_seasons.33             1.0540045                 s.33                 True
# initial_seasons.34             1.0632994                 s.34                 True
# initial_seasons.35             1.0696943                 s.35                 True
# initial_seasons.36             1.0757177                 s.36                 True
# initial_seasons.37             1.0789017                 s.37                 True
# initial_seasons.38             1.0756863                 s.38                 True
# initial_seasons.39             1.0617831                 s.39                 True
# initial_seasons.40             1.0596807                 s.40                 True
# initial_seasons.41             1.0640354                 s.41                 True
# initial_seasons.42             1.0596941                 s.42                 True
# initial_seasons.43             1.0501336                 s.43                 True
# initial_seasons.44             1.0508359                 s.44                 True
# initial_seasons.45             1.0490539                 s.45                 True
# initial_seasons.46             1.0323252                 s.46                 True
# initial_seasons.47             1.0234052                 s.47                 True
# initial_seasons.48             1.0225528                 s.48                 True
# initial_seasons.49             1.0178625                 s.49                 True
# initial_seasons.50             1.0201680                 s.50                 True
# initial_seasons.51             1.0178243                 s.51                 True
# initial_seasons.52             1.0152258                 s.52                 True
# initial_seasons.53             1.0085303                 s.53                 True
# initial_seasons.54             1.0102090                 s.54                 True
# initial_seasons.55             1.0174528                 s.55                 True
# initial_seasons.56             1.0172984                 s.56                 True
# initial_seasons.57             1.0111898                 s.57                 True
# initial_seasons.58             1.0128769                 s.58                 True
# initial_seasons.59             1.0209473                 s.59                 True
# initial_seasons.60             1.0242327                 s.60                 True
# initial_seasons.61             1.0203538                 s.61                 True
# initial_seasons.62             1.0226620                 s.62                 True
# initial_seasons.63             1.0221043                 s.63                 True
# initial_seasons.64             1.0246035                 s.64                 True
# initial_seasons.65             1.0282080                 s.65                 True
# initial_seasons.66             1.0353340                 s.66                 True
# initial_seasons.67             1.0440133                 s.67                 True
# initial_seasons.68             1.0470202                 s.68                 True
# initial_seasons.69             1.0504422                 s.69                 True
# initial_seasons.70             1.0489205                 s.70                 True
# initial_seasons.71             1.0432772                 s.71                 True
# initial_seasons.72             1.0253925                 s.72                 True
# initial_seasons.73             1.0207490                 s.73                 True
# initial_seasons.74             1.0202755                 s.74                 True
# initial_seasons.75             1.0324791                 s.75                 True
# initial_seasons.76             1.0341948                 s.76                 True
# initial_seasons.77             1.0399156                 s.77                 True
# initial_seasons.78             1.0547858                 s.78                 True
# initial_seasons.79             1.0655857                 s.79                 True
# initial_seasons.80             1.0628425                 s.80                 True
# initial_seasons.81             1.0706062                 s.81                 True
# initial_seasons.82             1.0833539                 s.82                 True
# initial_seasons.83             1.0869582                 s.83                 True
# initial_seasons.84             1.0891598                 s.84                 True
# initial_seasons.85             1.0932281                 s.85                 True
# initial_seasons.86             1.1009265                 s.86                 True
# initial_seasons.87             1.1022934                 s.87                 True
# initial_seasons.88             1.0908941                 s.88                 True
# initial_seasons.89             1.0932048                 s.89                 True
# initial_seasons.90             1.0906438                 s.90                 True
# initial_seasons.91             1.0891130                 s.91                 True
# initial_seasons.92             1.1004034                 s.92                 True
# initial_seasons.93             1.0971643                 s.93                 True
# initial_seasons.94             1.0937533                 s.94                 True
# initial_seasons.95             1.1046216                 s.95                 True
# initial_seasons.96             1.1110600                 s.96                 True
# initial_seasons.97             1.1065904                 s.97                 True
# initial_seasons.98             1.1095893                 s.98                 True
# initial_seasons.99             1.1190126                 s.99                 True
# initial_seasons.100            1.1129082                s.100                 True
# initial_seasons.101            1.0976469                s.101                 True
# initial_seasons.102            1.1105243                s.102                 True
# initial_seasons.103            1.1032240                s.103                 True
# initial_seasons.104            1.1036108                s.104                 True
# initial_seasons.105            1.1047789                s.105                 True
# initial_seasons.106            1.1025195                s.106                 True
# initial_seasons.107            1.0979512                s.107                 True
# initial_seasons.108            1.0947332                s.108                 True
# initial_seasons.109            1.1056286                s.109                 True
# initial_seasons.110            1.0955084                s.110                 True
# initial_seasons.111            1.1049439                s.111                 True
# initial_seasons.112            1.1122217                s.112                 True
# initial_seasons.113            1.1158990                s.113                 True
# initial_seasons.114            1.1280801                s.114                 True
# initial_seasons.115            1.1215143                s.115                 True
# initial_seasons.116            1.1263924                s.116                 True
# initial_seasons.117            1.1261666                s.117                 True
# initial_seasons.118            1.1252426                s.118                 True
# initial_seasons.119            1.1252703                s.119                 True
# initial_seasons.120            1.1187924                s.120                 True
# initial_seasons.121            1.1105396                s.121                 True
# initial_seasons.122            1.1110635                s.122                 True
# initial_seasons.123            1.1062707                s.123                 True
# initial_seasons.124            1.1161849                s.124                 True
# initial_seasons.125            1.1167426                s.125                 True
# initial_seasons.126            1.1166152                s.126                 True
# initial_seasons.127            1.1210212                s.127                 True
# initial_seasons.128            1.1310937                s.128                 True
# initial_seasons.129            1.1297948                s.129                 True
# initial_seasons.130            1.1286382                s.130                 True
# initial_seasons.131            1.1263932                s.131                 True
# initial_seasons.132            1.1327074                s.132                 True
# initial_seasons.133            1.1369315                s.133                 True
# initial_seasons.134            1.1363498                s.134                 True
# initial_seasons.135            1.1329921                s.135                 True
# initial_seasons.136            1.1436524                s.136                 True
# initial_seasons.137            1.1429462                s.137                 True
# initial_seasons.138            1.1410664                s.138                 True
# initial_seasons.139            1.1410009                s.139                 True
# initial_seasons.140            1.1411201                s.140                 True
# initial_seasons.141            1.1363329                s.141                 True
# initial_seasons.142            1.1256236                s.142                 True
# initial_seasons.143            1.1197335                s.143                 True
# initial_seasons.144            1.1187382                s.144                 True
# initial_seasons.145            1.1150950                s.145                 True
# initial_seasons.146            1.1139433                s.146                 True
# initial_seasons.147            1.1157205                s.147                 True
# initial_seasons.148            1.1040112                s.148                 True
# initial_seasons.149            1.0943690                s.149                 True
# initial_seasons.150            1.1087300                s.150                 True
# initial_seasons.151            1.0962587                s.151                 True
# initial_seasons.152            1.0869710                s.152                 True
# initial_seasons.153            1.0958140                s.153                 True
# initial_seasons.154            1.1162629                s.154                 True
# initial_seasons.155            1.1203563                s.155                 True
# initial_seasons.156            1.1302573                s.156                 True
# initial_seasons.157            1.1483849                s.157                 True
# initial_seasons.158            1.1467595                s.158                 True
# initial_seasons.159            1.1479640                s.159                 True
# initial_seasons.160            1.1484100                s.160                 True
# initial_seasons.161            1.1452203                s.161                 True
# initial_seasons.162            1.1537493                s.162                 True
# initial_seasons.163            1.1651689                s.163                 True
# initial_seasons.164            1.1799802                s.164                 True
# initial_seasons.165            1.1747105                s.165                 True
# initial_seasons.166            1.1848815                s.166                 True
# initial_seasons.167            1.1749507                s.167                 True
# initial_seasons.168            1.1777103                s.168                 True
# initial_seasons.169            1.1838751                s.169                 True
# initial_seasons.170            1.1834293                s.170                 True
# initial_seasons.171            1.1792702                s.171                 True
# initial_seasons.172            1.1809587                s.172                 True
# initial_seasons.173            1.1856706                s.173                 True
# initial_seasons.174            1.1903431                s.174                 True
# initial_seasons.175            1.1840144                s.175                 True
# initial_seasons.176            1.1760900                s.176                 True
# initial_seasons.177            1.1780381                s.177                 True
# initial_seasons.178            1.1663943                s.178                 True
# initial_seasons.179            1.1545339                s.179                 True
# initial_seasons.180            1.1462338                s.180                 True
# initial_seasons.181            1.1353028                s.181                 True
# initial_seasons.182            1.1297642                s.182                 True
# initial_seasons.183            1.1167035                s.183                 True
# initial_seasons.184            1.1439872                s.184                 True
# initial_seasons.185            1.1351633                s.185                 True
# initial_seasons.186            1.1333835                s.186                 True
# initial_seasons.187            1.1313813                s.187                 True
# initial_seasons.188            1.1327121                s.188                 True
# initial_seasons.189            1.1221155                s.189                 True
# initial_seasons.190            1.1309688                s.190                 True
# initial_seasons.191            1.1476468                s.191                 True
# initial_seasons.192            1.1563085                s.192                 True
# initial_seasons.193            1.1417147                s.193                 True
# initial_seasons.194            1.1479536                s.194                 True
# initial_seasons.195            1.1572372                s.195                 True
# initial_seasons.196            1.1473117                s.196                 True
# initial_seasons.197            1.1441338                s.197                 True
# initial_seasons.198            1.1468056                s.198                 True
# initial_seasons.199            1.1493632                s.199                 True
# initial_seasons.200            1.1514481                s.200                 True
# initial_seasons.201            1.1485185                s.201                 True
# initial_seasons.202            1.1321718                s.202                 True
# initial_seasons.203            1.1123471                s.203                 True
# initial_seasons.204            1.1121585                s.204                 True
# initial_seasons.205            1.1050905                s.205                 True
# initial_seasons.206            1.0946116                s.206                 True
# initial_seasons.207            1.0928425                s.207                 True
# initial_seasons.208            1.0834180                s.208                 True
# initial_seasons.209            1.0895058                s.209                 True
# initial_seasons.210            1.0996653                s.210                 True
# initial_seasons.211            1.1192497                s.211                 True
# initial_seasons.212            1.1190552                s.212                 True
# initial_seasons.213            1.1340049                s.213                 True
# initial_seasons.214            1.1326631                s.214                 True
# initial_seasons.215            1.1314228                s.215                 True
# initial_seasons.216            1.1357644                s.216                 True
# initial_seasons.217            1.1394045                s.217                 True
# initial_seasons.218            1.1364169                s.218                 True
# initial_seasons.219            1.1460566                s.219                 True
# initial_seasons.220            1.1283491                s.220                 True
# initial_seasons.221            1.1267959                s.221                 True
# initial_seasons.222            1.1190892                s.222                 True
# initial_seasons.223            1.1153018                s.223                 True
# initial_seasons.224            1.1165060                s.224                 True
# initial_seasons.225            1.1128136                s.225                 True
# initial_seasons.226            1.1127893                s.226                 True
# initial_seasons.227            1.1049816                s.227                 True
# initial_seasons.228            1.0957023                s.228                 True
# initial_seasons.229            1.0969305                s.229                 True
# initial_seasons.230            1.0981863                s.230                 True
# initial_seasons.231            1.1082064                s.231                 True
# initial_seasons.232            1.1104160                s.232                 True
# initial_seasons.233            1.1210298                s.233                 True
# initial_seasons.234            1.1287164                s.234                 True
# initial_seasons.235            1.1225675                s.235                 True
# initial_seasons.236            1.1293520                s.236                 True
# initial_seasons.237            1.1258668                s.237                 True
# initial_seasons.238            1.1168695                s.238                 True
# initial_seasons.239            1.1146986                s.239                 True
# initial_seasons.240            1.1156072                s.240                 True
# initial_seasons.241            1.1050878                s.241                 True
# initial_seasons.242            1.1148670                s.242                 True
# initial_seasons.243            1.1098621                s.243                 True
# initial_seasons.244            1.1127061                s.244                 True
# initial_seasons.245            1.1062737                s.245                 True
# initial_seasons.246            1.1213869                s.246                 True
# initial_seasons.247            1.1104042                s.247                 True
# initial_seasons.248            1.1069639                s.248                 True
# initial_seasons.249            1.1067671                s.249                 True
# initial_seasons.250            1.1119947                s.250                 True
# initial_seasons.251            1.1112888                s.251                 True
# initial_seasons.252            1.1162072                s.252                 True
# initial_seasons.253            1.1110253                s.253                 True
# initial_seasons.254            1.1156161                s.254                 True
# initial_seasons.255            1.1035830                s.255                 True
# initial_seasons.256            1.1067820                s.256                 True
# initial_seasons.257            1.1065992                s.257                 True
# initial_seasons.258            1.1163670                s.258                 True
# initial_seasons.259            1.1283456                s.259                 True
# initial_seasons.260            1.1314151                s.260                 True
# initial_seasons.261            1.1242969                s.261                 True
# initial_seasons.262            1.1279713                s.262                 True
# initial_seasons.263            1.1299016                s.263                 True
# initial_seasons.264            1.1277567                s.264                 True
# initial_seasons.265            1.1284491                s.265                 True
# initial_seasons.266            1.1249448                s.266                 True
# initial_seasons.267            1.1304961                s.267                 True
# initial_seasons.268            1.1270689                s.268                 True
# initial_seasons.269            1.1227982                s.269                 True
# initial_seasons.270            1.1285327                s.270                 True
# initial_seasons.271            1.1339193                s.271                 True
# initial_seasons.272            1.1334844                s.272                 True
# initial_seasons.273            1.1289067                s.273                 True
# initial_seasons.274            1.1195409                s.274                 True
# initial_seasons.275            1.1174030                s.275                 True
# initial_seasons.276            1.1572666                s.276                 True
# initial_seasons.277            1.1626173                s.277                 True
# initial_seasons.278            1.1558046                s.278                 True
# initial_seasons.279            1.1661131                s.279                 True
# initial_seasons.280            1.1607314                s.280                 True
# initial_seasons.281            1.1593296                s.281                 True
# initial_seasons.282            1.1603039                s.282                 True
# initial_seasons.283            1.1579540                s.283                 True
# initial_seasons.284            1.1607572                s.284                 True
# initial_seasons.285            1.1625258                s.285                 True
# initial_seasons.286            1.1639038                s.286                 True
# initial_seasons.287            1.1730082                s.287                 True
# initial_seasons.288            1.1813117                s.288                 True
# initial_seasons.289            1.1772967                s.289                 True
# initial_seasons.290            1.1763604                s.290                 True
# initial_seasons.291            1.1761851                s.291                 True
# initial_seasons.292            1.1764159                s.292                 True
# initial_seasons.293            1.1757392                s.293                 True
# initial_seasons.294            1.1758266                s.294                 True
# initial_seasons.295            1.1751757                s.295                 True
# initial_seasons.296            1.1786637                s.296                 True
# initial_seasons.297            1.1776278                s.297                 True
# initial_seasons.298            1.1831061                s.298                 True
# initial_seasons.299            1.1816000                s.299                 True
# initial_seasons.300            1.1792220                s.300                 True
# initial_seasons.301            1.1680638                s.301                 True
# initial_seasons.302            1.1552471                s.302                 True
# initial_seasons.303            1.1539495                s.303                 True
# initial_seasons.304            1.1470585                s.304                 True
# initial_seasons.305            1.1657796                s.305                 True
# initial_seasons.306            1.1529349                s.306                 True
# initial_seasons.307            1.1682846                s.307                 True
# initial_seasons.308            1.1581092                s.308                 True
# initial_seasons.309            1.1476100                s.309                 True
# initial_seasons.310            1.1459776                s.310                 True
# initial_seasons.311            1.1455632                s.311                 True
# initial_seasons.312            1.1437256                s.312                 True
# initial_seasons.313            1.1363510                s.313                 True
# initial_seasons.314            1.1520923                s.314                 True
# initial_seasons.315            1.1549173                s.315                 True
# initial_seasons.316            1.1483054                s.316                 True
# initial_seasons.317            1.1619569                s.317                 True
# initial_seasons.318            1.1649310                s.318                 True
# initial_seasons.319            1.1707015                s.319                 True
# initial_seasons.320            1.1751499                s.320                 True
# initial_seasons.321            1.1718626                s.321                 True
# initial_seasons.322            1.1608532                s.322                 True
# initial_seasons.323            1.1514635                s.323                 True
# initial_seasons.324            1.1509515                s.324                 True
# initial_seasons.325            1.1581979                s.325                 True
# initial_seasons.326            1.1268051                s.326                 True
# initial_seasons.327            1.1208540                s.327                 True
# initial_seasons.328            1.1437363                s.328                 True
# initial_seasons.329            1.1313348                s.329                 True
# initial_seasons.330            1.1454725                s.330                 True
# initial_seasons.331            1.1385321                s.331                 True
# initial_seasons.332            1.1260991                s.332                 True
# initial_seasons.333            1.1353650                s.333                 True
# initial_seasons.334            1.1374316                s.334                 True
# initial_seasons.335            1.1412563                s.335                 True
# initial_seasons.336            1.1132224                s.336                 True
# initial_seasons.337            1.1175384                s.337                 True
# initial_seasons.338            1.1022279                s.338                 True
# initial_seasons.339            1.0857903                s.339                 True
# initial_seasons.340            1.0870169                s.340                 True
# initial_seasons.341            1.0931829                s.341                 True
# initial_seasons.342            1.0991458                s.342                 True
# initial_seasons.343            1.0598339                s.343                 True
# initial_seasons.344            1.0496879                s.344                 True
# initial_seasons.345            1.0487711                s.345                 True
# initial_seasons.346            1.0640551                s.346                 True
# initial_seasons.347            1.0602018                s.347                 True
# initial_seasons.348            1.0445215                s.348                 True
# initial_seasons.349            1.0160445                s.349                 True
# initial_seasons.350            1.0057200                s.350                 True
# initial_seasons.351            0.9927911                s.351                 True
# initial_seasons.352            0.9916903                s.352                 True
# initial_seasons.353            0.9992364                s.353                 True
# initial_seasons.354            0.9779820                s.354                 True
# initial_seasons.355            0.9556015                s.355                 True
# initial_seasons.356            0.9509003                s.356                 True
# initial_seasons.357            0.9401137                s.357                 True
# initial_seasons.358            0.9340718                s.358                 True
# initial_seasons.359            0.9393659                s.359                 True
# ----------------------------------------------------------------------------------
# """

# %%
predictTrainSM=emamodel.predict(min(trainData.index),max(trainData.index))

# %%
predictTrainSM.plot()
trainData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
predictTestSM=emamodel.predict(min(testData.index),max(testData.index))

# %%
predictTestSM.plot()
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
mse = mean_squared_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Squared Error (MSE) = ',mse)
rmse = np.round(np.sqrt(mse),2)
print(f'Root Mean Squared Error (RMSE) = ',rmse)
mae = mean_absolute_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Absolute Error (MAE)  = ', mae)
mape = mean_absolute_percentage_error(trainData['Adj Close'],predictTrainSM)
print(f'Mean Absolute Percentage Error (MAPE)  = ', mape)
# Out:
# Mean Squared Error (MSE) =  2.286363477643113
# Root Mean Squared Error (RMSE) =  1.51
# Mean Absolute Error (MAE)  =  1.0796632851246957
# Mean Absolute Percentage Error (MAPE)  =  0.010971651397669186

# %%
mse = mean_squared_error(testData['Adj Close'],predictTestSM)
print(f'Mean Squared Error (MSE) = ',mse)
rmse = np.round(np.sqrt(mse),2)
print(f'Root Mean Squared Error (RMSE) = ',rmse)
mae = mean_absolute_error(testData['Adj Close'],predictTestSM)
print(f'Mean Absolute Error (MAE)  = ', mae)
mape = mean_absolute_percentage_error(testData['Adj Close'],predictTestSM)
print(f'Mean Absolute Percentage Error (MAPE)  = ', mape)
# Out:
# Mean Squared Error (MSE) =  409.0259668215695
# Root Mean Squared Error (RMSE) =  20.22
# Mean Absolute Error (MAE)  =  15.277698298585308
# Mean Absolute Percentage Error (MAPE)  =  0.06956358500251844

# %%
trainData["Adj Close"].plot()
predictTestSM.plot()
testData["Adj Close"].plot()
# Out:
# <Axes: >

# %%
import pickle

pickle.dump(emamodel, open('model.pkl', 'wb'))

# %%
onemonthprediction=emamodel.predict('2020-01-01','2020-02-01')

# %%
onemonthprediction.plot()
# Out:
# <Axes: >

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(trainData, model='additive',period=240)

# %%
decomposition.plot()

# %%
pacf=plot_pacf(decomposition.seasonal)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# P=1

# %%
pacf=plot_acf(decomposition.seasonal)

# %% [markdown]
# Q=21

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
sarima_model = SARIMAX(trainData,
                       order=(1,1,1),
                       seasonal_order=(1,1,0,57))
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %%
results = sarima_model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                           Adj Close   No. Observations:                 1825
# Model:             SARIMAX(1, 1, 1)x(1, 1, [], 57)   Log Likelihood               -3822.016
# Date:                             Mon, 10 Apr 2023   AIC                           7652.032
# Time:                                     20:03:42   BIC                           7673.940
# Sample:                                 01-03-2012   HQIC                          7660.127
#                                       - 12-31-2018
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2761      0.203     -1.359      0.174      -0.674       0.122
# ma.L1          0.3482      0.199      1.747      0.081      -0.042       0.739
# ar.S.L57      -0.5125      0.018    -28.191      0.000      -0.548      -0.477
# sigma2         4.3855      0.083     52.722      0.000       4.222       4.548
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):              1397.83
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.94   Skew:                            -0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
predict_train=results.predict(min(trainData.index),max(trainData.index))

# %%
trainData["Adj Close"].plot(label="Original")
predict_train.plot(label="prediction")
plt.legend(loc="best")
plt.show()

# %%
predict_test=results.predict(min(testData.index),max(testData.index))

# %%
testData["Adj Close"].plot(label="Original")
predict_test.plot(label="prediction")
plt.legend(loc="best")
plt.show()

# %%
np.sqrt(mean_squared_error(trainData,predict_train))
# Out:
# 2.4657702186498804

# %%
np.sqrt(mean_squared_error(testData,predict_test))
# Out:
# 125.01436002633996
